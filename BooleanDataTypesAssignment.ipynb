# %%
# Question: Check if a number is both even and greater than 10

number = 16
is_even = number % 2 == 0
is_greater_than_10 = number > 10
result = is_even and is_greater_than_10
print(f"Number:{number}")
print(f"Is Even: {is_even}")
print(f"Even and Greater than 10: {result}")
# Out:
# Number:16
# Is Even: True
# Even and Greater than 10: True

# %%
# Question 1: Check if 25 is greater than 20 and less than 30
number = 25
is_greret_than_20 = number > 20
is_less_than_30 = number < 30
result = is_greret_than_20 and is_less_than_30

print(f"Greater Than 20 and Less Than 30: ", result)
# Out:
# Greater Than 20 and Less Than 30:  True

# %%
# Question 2: Check if string "python" is equal to "Python" (case sensitive)

s1 = "python"
s2 = "Python"

result = s1 == s2
print(result)
# Out:
# False

# %%
# Question 3: Check if 15 is divisible by both 3 and 5

number = 15
is_divisible_by_3 = number % 3 == -0
is_divisible_by_5 = number % 5 == 0
result = is_divisible_by_3 and is_divisible_by_5

print(f"15 is divisible by both 3 and 5: ", result)
# Out:
# 15 is divisible by both 3 and 5:  True

# %%
# Question 4: Check if 7 is not equal to 8
number = 7
result = number == 8
print(f"7 is not equal to 8: " , result)
# Out:
# 7 is not equal to 8:  False

# %%
# Question 5: Check if 100 is greater than 50 or less than 25
number = 100
is_greater_than_50 = number > 50
is_less_than_25 = number < 25
result = is_greater_than_50 or is_less_than_25

print(f"100 is greater than 50 or less than 25: ",result)
# Out:
# 100 is greater than 50 or less than 25:  True

# %%
# Question 6: Check if 0 is falsy in Python
if 0:
    print("Truthy")
else:
    print("Falsy")
# Out:
# Falsy

# %%
# Question 7: Check if empty string "" is falsy in Python
if "":
    print("Truthy")
else:
    print("Falsy")
# Out:
# Falsy

# %%
# Question 8: Check if 42 is truthy in Python
if 42:
    print("Truthy")
else:
    print("Falsy")
# Out:
# Truthy

# %%
# Question 9: Check if 10 is between 5 and 15 (inclusive)
number = 10
result = 5 <= number <= 15

print(f"10 is between 5 and 15: ", result)
# Out:
# 10 is between 5 and 15:  True

# %%
# Question 10: Check if 3.14 is greater than 3 and less than 4
number = 3.14
greater_than_3 = number > 3
less_than_4 = number < 4
result = greater_than_3 and less_than_4

print(f"3.14 is greater than 3 and less than 4: ", result)
# Out:
# 3.14 is greater than 3 and less than 4:  True
