# %%
# Question: Create a complex number and find its conjugate
z = 3 + 4j
conjugate = z.conjugate()
magnitude = abs(z)
print(f" Complex Number: ", z)
print(f" Conjugate: ", conjugate)
print(f" Magnitude: ", magnitude)
# Out:
#  Complex Number:  (3+4j)
#  Conjugate:  (3-4j)
#  Magnitude:  5.0

# %%
# Question 1: Create complex number 5 + 3j

z = complex(5, 3)
print(z)
# Out:
# (5+3j)

# %%
# Question 2: Find the real part of complex number 7 - 2j
z = 7 - 2j
real_part = z.real
imag_part = z.imag
print(f"Number: ", z)
print(f"Real Part: ", real_part)
print(f"Imagenari Part: ", imag_part)
# Out:
# Number:  (7-2j)
# Real Part:  7.0
# Imagenari Part:  -2.0

# %%
# Question 3: Find the imaginary part of complex number 4 + 6j
c_number = 4 + 6j
result = c_number.imag
print(f"Imaginary part of complex number 4 + 6j: ", result)
# Out:
# Imaginary part of complex number 4 + 6j:  6.0

# %%
# Question 4: Add two complex numbers: (3 + 2j) and (1 + 4j)

a=(3 + 2j)
b=(1 + 4j)
result = a + b
print(f"Addition of {a} and {b}: ", result)
# Out:
# Addition of (3+2j) and (1+4j):  (4+6j)

# %%
# Question 5: Multiply two complex numbers: (2 + 3j) and (1 + 2j)
a = (2 + 3j)
b = (1 + 2j)

result = a * b
print(f"Multiplication of {a} and {b}: ", result)
# Out:
# Multiplication of (2+3j) and (1+2j):  (-4+7j)

# %%
# Question 6: Find the magnitude of complex number 6 + 8j
z = 6 + 8j
result = abs(z)
print(f"Manitude of {z}: ", result)
# Out:
# Manitude of (6+8j):  10.0

# %%
# Question 7: Find the conjugate of complex number 5 - 7j
z = 5 - 7j
result = z.conjugate()
print(f"Conjugare of {z}: ", result)
# Out:
# Conjugare of (5-7j):  (5+7j)

# %%
# Question 8: Subtract complex numbers: (10 + 5j) - (3 + 2j)
a = (10 + 5j)
b = (3 + 2j)
result = a - b
print(f"Subtraction of {a} and {b}: ", result)
# Out:
# Subtraction of (10+5j) and (3+2j):  (7+3j)

# %%
# Question 9: Divide complex numbers: (8 + 6j) / (2 + 1j)
a = (8 + 6j)
b = (2 + 1j)
result = a / b
print(f"Division of {a} and {b}: ", result)
# Out:
# Division of (8+6j) and (2+1j):  (4.4+0.8j)

# %%
# Question 10: Find the phase angle of complex number 1 + 1j
import cmath
z = 1 + 1j
phase_angle = cmath.phase(z)
phase_angle_in_degree = phase_angle * 180 / cmath.pi
print(f"Phase angle of {z}: ", phase_angle)
print(f"Phase angle of {z} in Degree: ", phase_angle_in_degree)
# Out:
# Phase angle of (1+1j):  0.7853981633974483
# Phase angle of (1+1j) in Degree:  45.0
