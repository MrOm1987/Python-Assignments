# %%
# Question: Check if a variable is None
variable = None
is_none = variable is None
print(f"Variable : {variable}")
print(f"Is None : {is_none}")
# Out:
# Variable : None
# Is None : True

# %%
# Question 1: Create a variable and assign None to it
v = None
print(f"Variable : {v}")
# Out:
# Variable : None

# %%
# Question 2: Check if None equals None
v = None
result = v == None
print(f"Variable:{v} is equal to None? :", result)
# Out:
# Variable:None is equal to None? : True

# %%
# Question 3: Check if None is None
variable = None
is_none = variable is None
print(f"Variable : {variable}")
print(f"Is None : {is_none}")
# Out:
# Variable : None
# Is None : True

# %%
# Question 4: Check if 0 is None
result = 0 == None
print(f"0 is None?:" ,result)
# Out:
# 0 is None?: False

# %%
# Question 5: Check if empty string is None
result = "" == None
print(f'"" is None?:' ,result)
# Out:
# "" is None?: False

# %%
# Question 6: Check if False is None
result = False == None
print(f'False is None?:' ,result)
# Out:
# False is None?: False

# %%
# Question 7: Check if empty list is None
result = [] == None
print(f'[]:' ,result)
# Out:
# []: False

# %%
# Question 8: Check if empty dictionary is None
result = {} == None
print("{}:" ,result)
# Out:
# {}: False

# %%
# Question 9: Check if empty tuple is None
result = () == None
print("():" ,result)
# Out:
# (): False

# %%
# Question 10: Check if empty set is None
empty_set = set()
print(empty_set == None)
# Out:
# False
