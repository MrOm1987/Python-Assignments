# %%
two_nums = [1,2]
print(sum(two_nums))
# Out:
# 3

# %%
five_even = [2, 4, 6, 8, 10]
total = sum(five_even)

print(f"First five even numbers: {five_even}")
print(f"Sum of five numbers: {total}")
# Out:
# First five even numbers: [2, 4, 6, 8, 10]
# Sum of five numbers: 30
